# %%
path = 'AD_all_patients.csv'

# %%
import os
import glob
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
)

import torch
from torch_geometric.data import HeteroData, download_url, extract_zip
from torch_geometric.transforms import RandomLinkSplit, ToUndirected

# %%
# Visualize tabular dataset before proceeding with any node/edge/link transforms
main=pd.read_csv(path)
print(main)
# Out:
#               Fp1       Fp2        F7        F3         Fz        F4  \
# 0       116.99375  41.09375  66.69375 -64.50625 -126.40625   8.39375
# 1       115.93125  38.63125  64.73125 -64.66875 -125.26875   8.73125
# 2       115.72500  38.32500  66.02500 -62.67500 -135.37500   9.02500
# 3       120.15625  40.75625  71.05625 -59.54375 -148.34375  12.15625
# 4       119.50000  39.50000  71.30000 -59.20000 -125.50000  14.80000
# ...           ...       ...       ...       ...        ...       ...
# 848635   16.32500  43.62500  68.62500   8.52500  -56.37500   0.82500
# 848636   16.24375  42.34375  70.64375  10.64375  -50.75625   1.84375
# 848637   13.93125  36.93125  72.73125  12.43125  -45.36875   3.13125
# 848638   10.71875  32.71875  74.11875  13.01875  -43.88125   4.31875
# 848639    8.00000  28.60000  72.40000   9.30000  -47.00000   0.80000
#
#               F8        T3        C3        Cz        C4        T4         T5  \
# 0       22.49375  42.19375  53.29375   4.49375   2.49375  73.79375  129.29375
# 1       27.03125  43.23125  57.53125  11.13125   2.33125  72.23125  125.73125
# 2       29.42500  47.12500  49.92500  24.42500   1.22500  72.92500  123.22500
# 3       32.25625  49.05625  41.05625  12.75625   1.85625  73.55625  128.65625
# 4       28.50000  48.80000  42.20000  -1.20000   1.40000  70.30000  116.10000
# ...          ...       ...       ...       ...       ...       ...        ...
# 848635 -17.77500 -50.47500 -56.17500 -21.67500 -23.67500  35.42500  -21.67500
# 848636 -22.85625 -49.25625 -53.55625 -22.15625 -21.65625  35.04375  -20.25625
# 848637 -28.26875 -48.66875 -45.36875 -24.36875 -17.46875  30.93125  -18.26875
# 848638 -23.48125 -45.48125 -43.08125 -25.28125 -17.38125  26.51875  -18.58125
# 848639 -13.20000 -43.00000 -44.60000 -16.50000 -19.10000  25.20000  -18.60000
#
#               P3         Pz         P4  status
# 0        0.09375 -124.90625 -245.50625       1
# 1       -5.46875 -123.06875 -248.76875       1
# 2       -3.07500 -129.97500 -246.27500       1
# 3       -0.14375 -133.24375 -242.04375       1
# 4        3.40000 -129.00000 -240.90000       1
# ...          ...        ...        ...     ...
# 848635  22.02500   45.22500    7.22500       0
# 848636  16.74375   44.14375    2.84375       0
# 848637  11.93125   53.43125   -7.66875       0
# 848638  11.21875   53.61875   -9.08125       0
# 848639   5.90000   53.30000   -1.50000       0
#
# [848640 rows x 17 columns]

# %%
#separate into labels & features and run a random forest
